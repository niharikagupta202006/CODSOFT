# %% [markdown]
# <a href="https://colab.research.google.com/github/niharikagupta202006/CODSOFT/blob/main/task1_ToDoList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os

# File to store tasks
taskfile = "tasks.json"

# Load tasks from file
def load_tasks():
    if os.path.exists(taskfile):
        with open(taskfile, "r") as file:
            return json.load(file)
    return []

# Save tasks to file
def save_tasks(tasks):
    with open(taskfile, "w") as file:
        json.dump(tasks, file)

# Display tasks
def view_tasks(tasks):
    if not tasks:
        print("\nNo tasks found!\n")
    else:
        print("\nYour To-Do List:")
        for i, task in enumerate(tasks, start=1):
            status = "✅" if task['done'] else "❌"
            print(f"{i}. {task['title']} [{status}]")
    print()

# Add a new task
def add_task(tasks):
    title = input("Enter task title: ")
    tasks.append({"title": title, "done": False})
    save_tasks(tasks)
    print("Task added!\n")

# Mark task as complete/incomplete
def update_task(tasks):
    view_tasks(tasks)
    try:
        task_no = int(input("Enter task number to update: ")) - 1
        if 0 <= task_no < len(tasks):
            tasks[task_no]['done'] = not tasks[task_no]['done']
            save_tasks(tasks)
            print("Task updated!\n")
        else:
            print("Invalid task number!\n")
    except ValueError:
        print("Please enter a valid number!\n")

# Delete a task
def delete_task(tasks):
    view_tasks(tasks)
    try:
        task_no = int(input("Enter task number to delete: ")) - 1
        if 0 <= task_no < len(tasks):
            deleted = tasks.pop(task_no)
            save_tasks(tasks)
            print(f"Deleted task: {deleted['title']}\n")
        else:
            print("Invalid task number!\n")
    except ValueError:
        print("Please enter a valid number!\n")

# Main menu
def main():
    tasks = load_tasks()
    while True:
        print("----- TO-DO LIST MENU -----")
        print("1. View tasks")
        print("2. Add task")
        print("3. Update task (mark complete/incomplete)")
        print("4. Delete task")
        print("5. Exit")
        choice = input("Enter choice: ")

        if choice == "1":
            view_tasks(tasks)
        elif choice == "2":
            add_task(tasks)
        elif choice == "3":
            update_task(tasks)
        elif choice == "4":
            delete_task(tasks)
        elif choice == "5":
            print("Goodbye!")
            break
        else:
            print("Invalid choice. Try again.\n")

if __name__ == "__main__":
    main()
# Out:
# ----- TO-DO LIST MENU -----
# 1. View tasks
# 2. Add task
# 3. Update task (mark complete/incomplete)
# 4. Delete task
# 5. Exit
# Enter choice: 2
# Enter task title: STUDIES
# Task added!
#
# ----- TO-DO LIST MENU -----
# 1. View tasks
# 2. Add task
# 3. Update task (mark complete/incomplete)
# 4. Delete task
# 5. Exit
# Enter choice: 1
#
# Your To-Do List:
# 1. STUDIES [❌]
#
# ----- TO-DO LIST MENU -----
# 1. View tasks
# 2. Add task
# 3. Update task (mark complete/incomplete)
# 4. Delete task
# 5. Exit
# Enter choice: 3
#
# Your To-Do List:
# 1. STUDIES [❌]
#
# Enter task number to update: 1
# Task updated!
#
# ----- TO-DO LIST MENU -----
# 1. View tasks
# 2. Add task
# 3. Update task (mark complete/incomplete)
# 4. Delete task
# 5. Exit
# Enter choice: 1
#
# Your To-Do List:
# 1. STUDIES [✅]
#
# ----- TO-DO LIST MENU -----
# 1. View tasks
# 2. Add task
# 3. Update task (mark complete/incomplete)
# 4. Delete task
# 5. Exit
